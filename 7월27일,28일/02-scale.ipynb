# %%
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris

pd.set_option("display.max_columns", 100)
sns.set_style("whitegrid")

# %% [markdown]
# # Data Loading
#
# [Ref] https://en.wikipedia.org/wiki/Iris_flower_data_set

# %%
_data = load_iris()
data = _data["data"]
feature_names = _data["feature_names"]

df = pd.DataFrame(data, columns=feature_names)
df["target"] = _data["target"]

df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %% [markdown]
# # Preprocessing

# %%
# Redefine target labels
target_mapping = {
    0: "Iris-Setosa",
    1: "Iris-Versicolour",
    2: "Iris-Virginica",
}
df["target"] = df["target"].map(target_mapping)

df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#         target
# 0  Iris-Setosa
# 1  Iris-Setosa
# 2  Iris-Setosa
# 3  Iris-Setosa
# 4  Iris-Setosa

# %%
df["target"].unique()
# Out:
# <StringArray>
# ['Iris-Setosa', 'Iris-Versicolour', 'Iris-Virginica']
# Length: 3, dtype: str

# %% [markdown]
# # EDA

# %%
df.groupby("target").describe()
# Out:
#                  sepal length (cm)                                         \
#                              count   mean       std  min    25%  50%  75%
# target
# Iris-Setosa                   50.0  5.006  0.352490  4.3  4.800  5.0  5.2
# Iris-Versicolour              50.0  5.936  0.516171  4.9  5.600  5.9  6.3
# Iris-Virginica                50.0  6.588  0.635880  4.9  6.225  6.5  6.9
#
#                       sepal width (cm)                                    \
#                   max            count   mean       std  min    25%  50%
# target
# Iris-Setosa       5.8             50.0  3.428  0.379064  2.3  3.200  3.4
# Iris-Versicolour  7.0             50.0  2.770  0.313798  2.0  2.525  2.8
# Iris-Virginica    7.9             50.0  2.974  0.322497  2.2  2.800  3.0
#
#                              petal length (cm)                             \
#                     75%  max             count   mean       std  min  25%
# target
# Iris-Setosa       3.675  4.4              50.0  1.462  0.173664  1.0  1.4
# Iris-Versicolour  3.000  3.4              50.0  4.260  0.469911  3.0  4.0
# Iris-Virginica    3.175  3.8              50.0  5.552  0.551895  4.5  5.1
#
#                                    petal width (cm)                        \
#                    50%    75%  max            count   mean       std  min
# target
# Iris-Setosa       1.50  1.575  1.9             50.0  0.246  0.105386  0.1
# Iris-Versicolour  4.35  4.600  5.1             50.0  1.326  0.197753  1.0
# Iris-Virginica    5.55  5.875  6.9             50.0  2.026  0.274650  1.4
#
#
#                   25%  50%  75%  max
# target
# Iris-Setosa       0.2  0.2  0.3  0.6
# Iris-Versicolour  1.2  1.3  1.5  1.8
# Iris-Virginica    1.8  2.0  2.3  2.5

# %%
sns.boxplot(
    x="target",
    y="petal length (cm)",
    data=df,
)
# Out:
# <Axes: xlabel='target', ylabel='petal length (cm)'>

# %%
plt.figure(figsize=(10, 10))

plt.subplot(221)
sns.boxplot(x="target", y="petal length (cm)", data=df)

plt.subplot(222)
sns.boxplot(x="target", y="petal width (cm)", data=df)

plt.show()

# %% [markdown]
# ## Standard Scaler
#
# (가정) 데이터셋의 컬럼별로 각각 단위가 다르고, Target 범주별 값의 분포 차이가 상이함

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

# %%
_df_scaled = scaler.fit_transform(df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 _df_scaled = scaler.fit_transform(df)
#
# File ~/workspace/window_home/7월15일/.venv/lib/python3.11/site-packages/sklearn/utils/_set_output.py:319, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     317 @wraps(f)
#     318 def wrapped(self, X, *args, **kwargs):
# --> 319     data_to_wrap = f(self, X, *args, **kwargs)
#     320     if isinstance(data_to_wrap, tuple):
#     321         # only wrap the first output for cross decomposition
#     322         return_tuple = (
#     323             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     324             *data_to_wrap[1:],
#     325         )
#
# File ~/workspace/window_home/7월15일/.venv/lib/python3.11/site-packages/sklearn/base.py:969, in TransformerMixin.fit_transform(self, X, y, **fit_params)
#     954         warnings.warn(
#     955             (
#     956                 f"This object ({self.__class__.__name__}) has a `transform`"
#    (...)    964             UserWarning,
#     965         )
#     967 if y is None:
#     968     # fit method of arity 1 (unsupervised transformation)
# --> 969     return self.fit(X, **fit_params).transform(X)
#     970 else:
#     971     # fit method of arity 2 (supervised transformation)
#     972     return self.fit(X, y, **fit_params).transform(X)
#
# File ~/workspace/window_home/7월15일/.venv/lib/python3.11/site-packages/sklearn/preprocessing/_data.py:928, in StandardScaler.fit(self, X, y, sample_weight)
#     926 # Reset internal state before fitting
#     927 self._reset()
# --> 928 return self.partial_fit(X, y, sample_weight)
#
# File ~/workspace/window_home/7월15일/.venv/lib/python3.11/site-packages/sklearn/base.py:1403, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1393     estimator._validate_params()
#    1395 with (
#    1396     config_context(
#    1397         skip_parameter_validation=(
#    (...)   1401     callback_management_context(estimator),
#    1402 ):
# -> 1403     return fit_method(estimator, *args, **kwargs)
#
# File ~/workspace/window_home/7월15일/.venv/lib/python3.11/site-packages/sklearn/preprocessing/_data.py:965, in StandardScaler.partial_fit(self, X, y, sample_weight)
#     963 xp, _, X_device = get_namespace_and_device(X)
#     964 first_call = not hasattr(self, "n_samples_seen_")
# --> 965 X = validate_data(
#     966     self,
#     967     X,
#     968     accept_sparse=("csr", "csc"),
#     969     dtype=supported_float_dtypes(xp, X_device),
#     970     ensure_all_finite="allow-nan",
#     971     reset=first_call,
#     972 )
#     973 n_features = X.shape[1]
#     975 callback_ctx = self._init_callback_context()
#
# File ~/workspace/window_home/7월15일/.venv/lib/python3.11/site-packages/sklearn/utils/validation.py:3038, in validate_data(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#    3036         out = X, y
#    3037 elif not no_val_X and no_val_y:
# -> 3038     out = check_array(X, input_name="X", **check_params)
#    3039 elif no_val_X and not no_val_y:
#    3040     out = _check_y(y, **check_params)
#
# File ~/workspace/window_home/7월15일/.venv/lib/python3.11/site-packages/sklearn/utils/validation.py:1035, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, ensure_all_finite, ensure_non_negative, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1033         array = xp.astype(array, dtype, copy=False)
#    1034     else:
# -> 1035         array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#    1036 except ComplexWarning as complex_warning:
#    1037     raise ValueError(
#    1038         "Complex data not supported\n{}\n".format(array)
#    1039     ) from complex_warning
#
# File ~/workspace/window_home/7월15일/.venv/lib/python3.11/site-packages/sklearn/utils/_array_api.py:976, in _asarray_with_order(array, dtype, order, copy, xp, device)
#     974     array = numpy.array(array, order=order, dtype=dtype)
#     975 else:
# --> 976     array = numpy.asarray(array, order=order, dtype=dtype)
#     978 # At this point array is a NumPy ndarray. We convert it to an array
#     979 # container that is consistent with the input's namespace.
#     980 return xp.asarray(array)
#
# File ~/workspace/window_home/7월15일/.venv/lib/python3.11/site-packages/pandas/core/generic.py:2027, in NDFrame.__array__(self, dtype, copy)
#    2023             )
#    2024         values = self._values
#    2025         if copy is None:
#    2026             # Note: branch avoids `copy=None` for NumPy 1.x support
# -> 2027             arr = np.asarray(values, dtype=dtype)
#    2028         else:
#    2029             arr = np.array(values, dtype=dtype, copy=copy)
#    2030
#
# ValueError: could not convert string to float: 'Iris-Setosa'

# %%
_df = df.iloc[:, :-1]
_df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
_df_scaled = scaler.fit_transform(_df)
df_scaled = pd.DataFrame(_df_scaled, columns=_df.columns)
df_scaled["target"] = df["target"]

df_scaled.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0          -0.900681          1.019004          -1.340227         -1.315444
# 1          -1.143017         -0.131979          -1.340227         -1.315444
# 2          -1.385353          0.328414          -1.397064         -1.315444
# 3          -1.506521          0.098217          -1.283389         -1.315444
# 4          -1.021849          1.249201          -1.340227         -1.315444
#
#         target
# 0  Iris-Setosa
# 1  Iris-Setosa
# 2  Iris-Setosa
# 3  Iris-Setosa
# 4  Iris-Setosa

# %%
fig, axes = plt.subplots(2, 2, figsize=(10, 10))
fig.suptitle("Standard Scaler")

sns.boxplot(x="target", y="petal length (cm)", data=df, ax=axes[0, 0])
sns.boxplot(x="target", y="petal width (cm)", data=df, ax=axes[0, 1])
sns.boxplot(x="target", y="petal length (cm)", data=df_scaled, ax=axes[1, 0])
sns.boxplot(x="target", y="petal width (cm)", data=df_scaled, ax=axes[1, 1])

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Min-Max Scaler
#
# - (가정) 데이터셋의 컬럼별로 각각 단위가 다르고, Target 범주별 값의 분포 차이가 상이함

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

# %%
_df_scaled = scaler.fit_transform(_df)
df_scaled = pd.DataFrame(_df_scaled, columns=_df.columns)
df_scaled["target"] = df["target"]

df_scaled.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0           0.222222          0.625000           0.067797          0.041667
# 1           0.166667          0.416667           0.067797          0.041667
# 2           0.111111          0.500000           0.050847          0.041667
# 3           0.083333          0.458333           0.084746          0.041667
# 4           0.194444          0.666667           0.067797          0.041667
#
#         target
# 0  Iris-Setosa
# 1  Iris-Setosa
# 2  Iris-Setosa
# 3  Iris-Setosa
# 4  Iris-Setosa

# %%
fig, axes = plt.subplots(2, 2, figsize=(10, 10))
plt.title("Min-Max Scaler")

sns.boxplot(x="target", y="petal length (cm)", data=df, ax=axes[0, 0])
sns.boxplot(x="target", y="petal width (cm)", data=df, ax=axes[0, 1])
sns.boxplot(x="target", y="petal length (cm)", data=df_scaled, ax=axes[1, 0])
sns.boxplot(x="target", y="petal width (cm)", data=df_scaled, ax=axes[1, 1])

plt.tight_layout()
plt.show()

# %% [markdown]
# ----
# End of Documents
